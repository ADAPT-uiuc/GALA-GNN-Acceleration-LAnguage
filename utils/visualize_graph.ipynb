# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import sparse
from scipy.sparse import coo_matrix

import matplotlib
img_sz = 100

# Sample sparse matrix
img_shape = (img_sz,img_sz)
matrix_data = np.zeros(img_shape)

row_file = np.load('/home/damitha/PycharmProjects/generate/data_save/coo_10000_20000_0.25_0.25_0.25_src.npy')
col = np.load('/home/damitha/PycharmProjects/generate/data_save/coo_10000_20000_0.25_0.25_0.25_dst.npy')

# row_file = np.load('/home/damitha/PycharmProjects/generate/data_save/coo_10000_20000_0.769_0.077_0.077_src.npy')
# col = np.load('/home/damitha/PycharmProjects/generate/data_save/coo_10000_20000_0.769_0.077_0.077_dst.npy')

# row_file = np.load('/home/damitha/PycharmProjects/generate/data_save/coo_10000_20000_0.4_0.4_0.1_src.npy')
# col = np.load('/home/damitha/PycharmProjects/generate/data_save/coo_10000_20000_0.4_0.4_0.1_dst.npy')

# row_file = np.load('/home/damitha/PycharmProjects/generate/data_save/coo_10000_20000_0.1_0.2_0.3_src.npy')
# col = np.load('/home/damitha/PycharmProjects/generate/data_save/coo_10000_20000_0.1_0.2_0.3_dst.npy')

# row_file = np.load('/home/damitha/PycharmProjects/generate/data_save/coo_10000_20000_0.4_0.1_0.1_src.npy')
# col = np.load('/home/damitha/PycharmProjects/generate/data_save/coo_10000_20000_0.4_0.1_0.1_dst.npy')

# row_file = np.load('/home/damitha/PycharmProjects/generate/data_save/coo_10000_20000_0.1_0.7_0.1_src.npy')
# col = np.load('/home/damitha/PycharmProjects/generate/data_save/coo_10000_20000_0.1_0.7_0.1_dst.npy')

n = row_file[0]
row = row_file[2:]
e = col.shape[0]

divs = (n + img_sz - 1) // img_sz  

for x in range(e):
    i = row[x] // divs
    j = col[x] // divs
    matrix_data[i][j] += 1
    
    
# # Create the COO matrix
# coo_matrix = coo_matrix((data, (row, col)), shape=(n, n))

# # Convert to CSR matrix
# sparse_matrix = coo_matrix.tocsr()

# Create the heatmap plot
plt.imshow(matrix_data, cmap='gray_r', interpolation='nearest', vmax=10)

# Add colorbar
plt.colorbar()

# Set labels and title
plt.xlabel('Columns')
plt.ylabel('Rows')
plt.title('Sparse Matrix')

# Display the plot
matplotlib.rcParams["figure.figsize"] = (8*2, 6*2) 
plt.show()
